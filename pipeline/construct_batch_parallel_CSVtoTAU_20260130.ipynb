# %% [markdown]
# # construct_batch_parallel_CSVtoTAU_20260130.ipynb
#
# Sample code for pipeline to demonstrate parallel processing

# %%
# all packages and utility programs loaded here

from rss_ringoccs_local_tools import *

# this also defines global variables

# %%
execute_this_cell = True
if execute_this_cell:

    from subprocess import DEVNULL, STDOUT
    
    description = 'Example code to produce TAU files for C + inner B ring for all bands, stations'
    
    version = '20260130a' # prepend this name to output *.sh file that contains sequence of python commands to run
    template_file = 'batch_parallel_CSVtoTAU_template-20260130a.py'
    rundir = 'runs_'+version # create subdirectory to hold template-filled *.py files for this run
    
    if not os.path.isdir(rundir):
        # print('The pipeline/'+rundir+'/ directory needs to exist and to contain the following symbolic links:')
        # print('rss_ringoccs_global_paths.py -> ../../rss_ringoccs_global_paths.py')
        # print('rss_ringoccs_local_tools.py -> ../../rss_ringoccs/tools/rss_ringoccs_local_tools.py')
        # print('Attempting to set up the '+rundir+'/ directory:')
        try:
            os.makedirs(rundir, exist_ok=True)
            directory_path = os.getcwd()+'/'+newdir+'/'
            command = ["ln", "-s","../../rss_ringoccs_global_paths.py"] 
            result = subprocess.run(command, cwd=directory_path, stdout=DEVNULL, stderr=DEVNULL)
            command = ["ln", "-s",".../../rss_ringoccs/tools/rss_ringoccs_local_tools.py"] 
            result = subprocess.run(command, cwd=directory_path, stdout=DEVNULL, stderr=DEVNULL)
            if not os.path.islink(directory_path +'rss_ringoccs_global_paths.py') or \
             not os.path.islink(directory_path +'rss_ringoccs_local_tools.py'):
                raise Exception("Failed to set up symbolic links")
            print('Successfully set up',rundir+'/')
        except:
            raise Exception("Unable to set up",rundir,"and required symbolic links.")

    outfile_root = rundir+'/batch_parallel_CSVtoTAU-'+version+'-'
    shell_file = 'batch_parallel_CSVtoTAU-'+version+'.sh'
    f = open(template_file,'r')
    contents = f.read().splitlines() # strips \n at end of each line
    f.close()

    # optionally, code can produce TAU file for a given trio of GEO, CAL, DLP
    # Ex:
    # data_dir = global_path_to_output + 'Rev133/Rev133E/Rev133E_RSS_2010_170_X43_E/' # note / at end
    # geo_file = data_dir + "RSS_2010_170_X43_E_GEO_20250408_0001.TAB"
    # cal_file = data_dir + "RSS_2010_170_X43_E_CAL_20250408_0001.TAB"
    # dlp_file = data_dir + "RSS_2010_170_X43_E_DLP_0050M_20250408_0001.TAB"


    # normal case is NOT to specify GEO,CAL,DLP, so use these definitions:
    
    geo_file = 'NONE'
    cal_file = 'NONE'
    dlp_file = 'NONE'

    res_kms = np.array([1.0, 0.500, 0.400, 0.300, 0.250, 0.200, 0.150, 0.100, 0.075, 0.050])
    min_res_km_Sband = 0.200 # don't try to process lower resolution S band than this value
    
    bands = ['X','K','S']
    
# not all of these include the C ring but code checks for this
    revs = [
            'Rev007',
            'Rev008',
            'Rev009',
            'Rev010',
            'Rev011',
            'Rev012',
            'Rev013',
            'Rev014',
            #'Rev028', #BAD EVENT - very distant
            'Rev044',
            'Rev046',
            'Rev053',
            'Rev054',
            'Rev056',
            'Rev057',
            'Rev058',
            'Rev060',
            'Rev063',
            'Rev064',
            'Rev067',
            'Rev079',
            'Rev084',
            'Rev089',
            'Rev123',
            'Rev125',
            'Rev133',
            'Rev137'
           ]            
    # specify restrictions on DSNs to include
    include_all_DSNs = True
    # otherwise, do something like this to get 70 m stations for X band
    DSN_include=['14','43','63'] #70m stations only
    
    dirs = ['I','E']
    psitypes = ['NewtonFilon12']
    
    names = ['C + inner B ring']
    inversion_range_mins = ['74400']
    inversion_range_maxs = ['97000'] # extend a bit to get wave in inner B ring

    trim_dlp = True # to save memory in multiprocessing, trip the DLP to this range
    processing_range_mins = ['60000']
    processing_range_maxs = ['110000']
    res_factor = 0.75

    wtype = 'kbmd20'
    drho_km = 0.0 # offset applied to radius scale
    output_creation_date = '*' # if searching for specific DLP file, set date of DLP file creation

    silent = False

    index = 0 # index of first output file
    with open(shell_file,'w') as fout:
        for res_km in res_kms:
            for Rev in revs:
                for direction in dirs:
                    for band in bands:
                        if band == 'S' and res_km < min_res_km_Sband:
                            continue # S band can't handle high resolution
                        files = get_CORSS_8001_TABfiles(CORSS_8001_all_filepaths=None,Rev=Rev,\
                                    DSN=None,direction=direction,local_path_to_data=global_path_to_data,
                                        local_path_to_tables = global_path_to_tables,silent=True)
                        DSNs = []
                        for file in files:
                            basename = os.path.basename(file)
                            
                            basenameband = basename[len('RSS_2005_123_K')-1]
                            basenamedir = basename[len('RSS_2005_123_K34_E')-1]
                            basenameDSN = basename[len('RSS_2005_123_K3')-1:len('RSS_2005_123_K34_')-1]
                            
                            if not include_all_DSNs and basenameDSN not in DSN_include and band != 'K':
                                continue
                            if Rev in file and band == basenameband and direction == basenamedir:
                                DSNs.append(band+basenameDSN)
                        for DSN in DSNs:
                            for psitype in psitypes:
                                for name,inversion_range_min,inversion_range_max,processing_range_min,processing_range_max in \
                                    zip(names,inversion_range_mins,inversion_range_maxs,processing_range_mins,processing_range_maxs):
                                    f = open(template_file,'r')
                                    contents = f.read().splitlines() # strips \n at end of each line
                                    f.close()
                                    for i,line in enumerate(contents):
                                        if '$DESCRIPTION' in line:     
                                            line= line.replace('$DESCRIPTION$',description)
                                            contents[i] = line                                            
                                        if '$GEO_FILEPATH$' in line:
                                            line= line.replace('$GEO_FILEPATH$',geo_file)
                                            contents[i] = line
                                        if '$CAL_FILEPATH$' in line:
                                            line= line.replace('$CAL_FILEPATH$',cal_file)
                                            contents[i] = line
                                        if '$DLP_FILEPATH$' in line:
                                            line= line.replace('$DLP_FILEPATH$',dlp_file)
                                            contents[i] = line
                                        if '$OUTPUT_CREATION_DATE$' in line:
                                            line= line.replace('$OUTPUT_CREATION_DATE$',output_creation_date)
                                            contents[i] = line
                                        if '$WTYPE$' in line:
                                            line= line.replace('$WTYPE$',wtype)
                                            contents[i] = line
                                        if '$RES_KM$' in line:
                                            line= line.replace('$RES_KM$','res_km = '+str(res_km))
                                            contents[i] = line
                                        if '$RES_FACTOR$' in line:
                                            line= line.replace('$RES_FACTOR$','res_factor = '+str(res_factor))
                                            contents[i] = line
                                        if '$DRHO_KM$' in line:
                                            line= line.replace('$DRHO_KM$','drho_km = '+str(drho_km))
                                            contents[i] = line
                                        if '$REV$' in line:
                                            line= line.replace('$REV$',Rev[3:])
                                            contents[i] = line
                                        if '$DIREC$' in line:
                                            line= line.replace('$DIREC$',direction)
                                            contents[i] = line
                                        if '$BAND$' in line:
                                            line= line.replace('$BAND$',DSN[0])
                                            contents[i] = line
                                        if '$DSN$' in line:
                                            line= line.replace('$DSN$',DSN[1:])
                                            contents[i] = line
                                        if '$PSITYPE$' in line:
                                            line= line.replace('$PSITYPE$',psitype)
                                            contents[i] = line
                                        if '$INVERSION_RANGE_MIN$' in line:
                                            line = line.replace('$INVERSION_RANGE_MIN$',inversion_range_min)
                                            contents[i] = line
                                        if '$INVERSION_RANGE_MAX$' in line:
                                            line = line.replace('$INVERSION_RANGE_MAX$',inversion_range_max)
                                            contents[i] = line
                                        if '$NAME$' in line:
                                            line = line.replace('$NAME$',name)
                                            contents[i] = line
                                        if '$SILENT$' in line:
                                            if silent == True:
                                                line = line.replace('$SILENT$','silent = True')
                                            else:
                                                line = line.replace('$SILENT$','silent = False')
                                            contents[i] = line
                                        if '$MAX_WORKERS$' in line:
                                            line = line.replace('$MAX_WORKERS$','max_workers = cpu_count()')
                                            contents[i] = line
                                        if '$TRIM_DLP$' in line:
                                            if trim_dlp == True:
                                               line = line.replace('$TRIM_DLP$','trim_dlp = True')
                                            else:
                                               line = line.replace('$TRIM_DLP$','trim_dlp = False')
                                            contents[i] = line
                                        if '$PROCESSING_RANGE_MIN$' in line:
                                            line = line.replace('$PROCESSING_RANGE_MIN$',processing_range_min)
                                            contents[i] = line
                                        if '$PROCESSING_RANGE_MAX$' in line:
                                            line = line.replace('$PROCESSING_RANGE_MAX$',processing_range_max)
                                            contents[i] = line
         
                                    outfile = outfile_root + f'{index:04d}.py'
                                    print(outfile, res_km,Rev,direction,DSN,psitype,name)
                                    index += 1
                                    with open(outfile,'w') as f:
                                        for line in contents:
                                            print(line,file=f)
                                    print('python3 '+outfile,file=fout)
    print('\nExecute this shell script from the rss_ringoccs/pipeline directory:')
    print(shell_file)
    print('\nOr, to run an individual job from the rss_ringoccs/pipeline directory, type:')
    print('python3 '+outfile,'\n')
    os.chmod(shell_file,0o777)
# Out:
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0000.py 1.0 Rev007 I X26 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0001.py 1.0 Rev007 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0002.py 1.0 Rev007 I K26 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0003.py 1.0 Rev007 I S43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0004.py 1.0 Rev007 E X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0005.py 1.0 Rev007 E X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0006.py 1.0 Rev007 E K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0007.py 1.0 Rev007 E S43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0008.py 1.0 Rev008 I X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0009.py 1.0 Rev008 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0010.py 1.0 Rev008 I K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0011.py 1.0 Rev008 I S43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0012.py 1.0 Rev008 E X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0013.py 1.0 Rev008 E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0014.py 1.0 Rev008 E K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0015.py 1.0 Rev008 E S63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0016.py 1.0 Rev009 E X14 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0017.py 1.0 Rev009 E X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0018.py 1.0 Rev009 E K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0019.py 1.0 Rev009 E S14 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0020.py 1.0 Rev010 I X14 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0021.py 1.0 Rev010 I X25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-0022.py 1.0 Rev010 I K25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-
E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1571.py 0.05 Rev054 E K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1572.py 0.05 Rev056 I X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1573.py 0.05 Rev056 I X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1574.py 0.05 Rev056 I K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1575.py 0.05 Rev056 E X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1576.py 0.05 Rev056 E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1577.py 0.05 Rev056 E K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1578.py 0.05 Rev057 I X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1579.py 0.05 Rev057 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1580.py 0.05 Rev057 I K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1581.py 0.05 Rev057 E X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1582.py 0.05 Rev057 E X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1583.py 0.05 Rev057 E K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1584.py 0.05 Rev058 I X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1585.py 0.05 Rev058 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1586.py 0.05 Rev058 I K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1587.py 0.05 Rev058 E X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1588.py 0.05 Rev058 E X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1589.py 0.05 Rev058 E K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1590.py 0.05 Rev060 I X14 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1591.py 0.05 Rev060 I X26 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1592.py 0.05 Rev060 I K26 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1593.py 0.05 Rev060 E X14 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1594.py 0.05 Rev060 E X26 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1595.py 0.05 Rev060 E K26 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1596.py 0.05 Rev063 I X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1597.py 0.05 Rev063 I X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1598.py 0.05 Rev063 I K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1599.py 0.05 Rev063 E X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1600.py 0.05 Rev063 E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1601.py 0.05 Rev063 E K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1602.py 0.05 Rev064 I X25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1603.py 0.05 Rev064 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1604.py 0.05 Rev064 I K25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1605.py 0.05 Rev064 E X25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1606.py 0.05 Rev064 E X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1607.py 0.05 Rev064 E K25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1608.py 0.05 Rev067 I X14 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1609.py 0.05 Rev067 I X25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1610.py 0.05 Rev067 I K25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1611.py 0.05 Rev067 E X14 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1612.py 0.05 Rev067 E X25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1613.py 0.05 Rev067 E K25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1614.py 0.05 Rev079 I X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1615.py 0.05 Rev079 I X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1616.py 0.05 Rev079 I K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1617.py 0.05 Rev079 E X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1618.py 0.05 Rev079 E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1619.py 0.05 Rev079 E K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1620.py 0.05 Rev084 I X54 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1621.py 0.05 Rev084 I X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1622.py 0.05 Rev084 I K54 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1623.py 0.05 Rev084 E X54 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1624.py 0.05 Rev084 E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1625.py 0.05 Rev084 E K54 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1626.py 0.05 Rev089 I X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1627.py 0.05 Rev089 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1628.py 0.05 Rev089 I K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1629.py 0.05 Rev089 E X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1630.py 0.05 Rev089 E X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1631.py 0.05 Rev089 E K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1632.py 0.05 Rev123 I X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1633.py 0.05 Rev123 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1634.py 0.05 Rev123 I K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1635.py 0.05 Rev123 E X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1636.py 0.05 Rev123 E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1637.py 0.05 Rev123 E K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1638.py 0.05 Rev125 I X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1639.py 0.05 Rev125 I X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1640.py 0.05 Rev125 I K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1641.py 0.05 Rev125 E X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1642.py 0.05 Rev125 E X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1643.py 0.05 Rev125 E K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1644.py 0.05 Rev133 I X15 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1645.py 0.05 Rev133 I X25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1646.py 0.05 Rev133 I K25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1647.py 0.05 Rev133 E X34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1648.py 0.05 Rev133 E X43 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1649.py 0.05 Rev133 E K34 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1650.py 0.05 Rev137 I X55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1651.py 0.05 Rev137 I X63 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1652.py 0.05 Rev137 I K55 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1653.py 0.05 Rev137 E X24 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1654.py 0.05 Rev137 E X25 NewtonFilon12 C + inner B ring
# runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1655.py 0.05 Rev137 E K25 NewtonFilon12 C + inner B ring
#
# Execute this shell script from the rss_ringoccs/pipeline directory:
# batch_parallel_CSVtoTAU-20260130a.sh
#
# Or, to run an individual job from the rss_ringoccs/pipeline directory, type:
# python3 runs_20260130a/batch_parallel_CSVtoTAU-20260130a-1655.py
